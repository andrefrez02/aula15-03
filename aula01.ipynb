# %% [markdown]
# <h1 style="cursor: pointer; color: #2244ff">APLICAÇÕES PARA INTERNET</h1>
# <h4 style="cursor: pointer; color: #5588ff">Aula 01 - Prof Chen</h4>

# %% [markdown]
# <html lang="pt">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Titulo da Página</title>
# </head>
# <body>
#     <h1>Isso é uma heading</h1>
#     <p>Isso é um paragrafo</p>
# </body>
# </html>
